# %% [markdown]
# # Imports

# %%
#Import relevant libraries
import numpy as np
import pandas as pd
import os
from PIL import Image
import csv


from sklearn.model_selection import train_test_split

# %matplotlib inline
import matplotlib.pyplot as plt

from keras.utils import to_categorical
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import seaborn as sns

# %% [markdown]
# # Load Images

# %% [markdown]
# #### Load Train Images

# %%
#this works as long as it is inside code/
train_path = "/".join(os.getcwd().replace("\\", "/").split("/")[:-1]) + "/archive/train/"
test_path = "/".join(os.getcwd().replace("\\", "/").split("/")[:-1]) + "/archive/test/"
images_path = "/".join(os.getcwd().replace("\\", "/").split("/")[:-1]) + "/archive/"

classes = os.listdir(train_path)

images = []
labels = []

#Read csv file
with open(images_path + 'Train.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    headers = next(csv_reader, None)

    for row in csv_reader:
        # Se quiser limitar a quantidade de imagens
        # if np.random.rand(1) < 0.9:
        #     continue

        img = Image.open(images_path + row[-1])

        #Crop image (This is given in the file, not calculated)
        img = img.crop((int(row[2]), int(row[3]), int(row[4]), int(row[5])))

        #needs to resize
        img = img.resize((30, 30))

        #Convert image to grayscale
#         img = img.convert('L')

        #Convert image to numpy array (Feature Extraction)
        img = np.array(img)#.flatten()
        # img.reshape(img.shape[0], 1)

        #Append image to list
        images.append(img)

        #Append label to list
        labels.append(np.uint8(row[6]))

X = np.array(images)
y = np.array(labels)
y = y.reshape(y.shape[0], 1)

#Split dataset, mantaining the proportion of samples in each class
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=68, stratify=y)

# %% [markdown]
# #### Load Test Images

# %%
test_images = []
test_labels = []

with open(images_path + 'Test.csv') as csv_file:
    csv_reader = csv.reader(csv_file)
    headers_test = next(csv_reader, None)  # skip the headers
    for row in csv_reader:

        img = Image.open(images_path + row[-1])

        #Crop image (This is given in the file, not calculated)
        img = img.crop((int(row[2]), int(row[3]), int(row[4]), int(row[5])))

        #needs to resize
        img = img.resize((30, 30))

        #Convert image to grayscale
#         img = img.convert('L')

        #Convert image to numpy array (Feature Extraction)
        img = np.array(img)#.flatten()
        # img.reshape(img.shape[0], 1)

        #Append image to list
        test_images.append(img)

        #Append label to list
        test_labels.append(np.uint8(row[6]))

X_test = np.array(test_images)
y_test = np.array(test_labels)

# %% [markdown]
# #### Normalize Data

# %%
# Normalize train, validation and test
X_train = X_train/255.
X_val = X_val/255.
X_test = X_test/255.

#Converting the labels into one hot encoding
y_train = to_categorical(y_train, len(classes))
y_val = to_categorical(y_val, len(classes))
y_test = to_categorical(y_test, len(classes))

#What is the shape of X_train, X_test, Y_train, Y_test
print("X_train shape: " + str(X_train.shape))
print("X_val shape: " + str(X_val.shape))
print("X_test shape: " + str(X_test.shape))
print("Y_train shape: " + str(y_train.shape))
print("Y_val shape: " + str(y_val.shape))
print("Y_test shape: " + str(y_test.shape))
    
# How many training and test examples ?
print("Number of training examples: " + str(X_train.shape[0]))
print("Number of validation examples: " + str(X_val.shape[0]))
print("Number of test examples: " + str(X_test.shape[0]))
# Out:
# X_train shape: (31367, 30, 30, 3)
# X_val shape: (7842, 30, 30, 3)
# X_test shape: (12630, 30, 30, 3)
# Y_train shape: (31367, 43)
# Y_val shape: (7842, 43)
# Y_test shape: (12630, 43)
# Number of training examples: 31367
# Number of validation examples: 7842
# Number of test examples: 12630

# %% [markdown]
# #### Labels

# %%
# Labels Translation
classes_translation = { 0:'Speed limit (20km/h)',
            1:'Speed limit (30km/h)', 
            2:'Speed limit (50km/h)', 
            3:'Speed limit (60km/h)', 
            4:'Speed limit (70km/h)', 
            5:'Speed limit (80km/h)', 
            6:'End of speed limit (80km/h)', 
            7:'Speed limit (100km/h)', 
            8:'Speed limit (120km/h)', 
            9:'No passing', 
            10:'No passing veh over 3.5 tons', 
            11:'Right-of-way at intersection', 
            12:'Priority road', 
            13:'Yield', 
            14:'Stop', 
            15:'No vehicles', 
            16:'Veh > 3.5 tons prohibited', 
            17:'No entry', 
            18:'General caution', 
            19:'Dangerous curve left', 
            20:'Dangerous curve right', 
            21:'Double curve', 
            22:'Bumpy road', 
            23:'Slippery road', 
            24:'Road narrows on the right', 
            25:'Road work', 
            26:'Traffic signals', 
            27:'Pedestrians', 
            28:'Children crossing', 
            29:'Bicycles crossing', 
            30:'Beware of ice/snow',
            31:'Wild animals crossing', 
            32:'End speed + passing limits', 
            33:'Turn right ahead', 
            34:'Turn left ahead', 
            35:'Ahead only', 
            36:'Go straight or right', 
            37:'Go straight or left', 
            38:'Keep right', 
            39:'Keep left', 
            40:'Roundabout mandatory', 
            41:'End of no passing', 
            42:'End no passing veh > 3.5 tons' }

# %% [markdown]
# # Analyse Dataset

# %% [markdown]
# #### Check class distribution in test dataset

# %%
# Check class distribution in test, train and validation
n_samples_train = sum(y_train==1)
n_samples_val = sum(y_val==1)
n_samples_test = sum(y_test==1)


fig, ax = plt.subplots(1, 3, figsize=(12, 4))
ax[0].bar(classes, n_samples_train)
ax[0].set_title('Train')
ax[1].bar(classes, n_samples_val)
ax[1].set_title('Validation')
ax[2].bar(classes, n_samples_test)
ax[2].set_title('Test')
fig.suptitle('Class distribution')
plt.show()

# %% [markdown]
# # Models

# %% [markdown]
# #### Imports

# %%
import warnings
warnings.filterwarnings('ignore',category=FutureWarning)
warnings.filterwarnings('ignore',category=DeprecationWarning)

from keras import layers
from keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling2D, MaxPooling2D, Dropout, GlobalMaxPooling2D, GlobalAveragePooling2D
from keras.models import Model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
import pydot
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model

import keras.backend as K
K.set_image_data_format('channels_last')

# %% [markdown]
# #### CNN with 1 convolutional layer

# %%
def CNN1(input_shape):
    X_input = Input(input_shape)

    X = ZeroPadding2D((3, 3))(X_input)

    # BLOCK 1: CONV -> BN -> RELU -> MAXP
    X = Conv2D(32, kernel_size=(3, 3), activation='relu', strides = (1, 1), name = 'conv0')(X)

    X = MaxPooling2D(pool_size=(2, 2), name='max_pool')(X)

    # Dropout offers a very computationally cheap and remarkably effective regularization method to reduce overfitting and improve generalization error in deep neural networks of all kinds.
    X = Dropout(0.2)(X)

    # FLATTEN X (means convert it to a vector) + FULLYCONNECTED
    X = Flatten()(X)
    X = Dense(256, activation='relu')(X)
    X = Dropout(0.3)(X)
    X = Dense(43, activation='softmax')(X)

    # Create model.
    model = Model(inputs = X_input, outputs = X, name='CNN1')

    return model

# %%
# Create the model
cnn1 = CNN1(X_train.shape[1:])

# Compile model
cnn1.compile(optimizer = "adam", loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# CNN model summary

cnn1.summary()
# Out:
# Model: "CNN1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 30, 30, 3)]       0
#
#  zero_padding2d (ZeroPadding  (None, 36, 36, 3)        0
#  2D)
#
#  conv0 (Conv2D)              (None, 34, 34, 32)        896
#
#  max_pool (MaxPooling2D)     (None, 17, 17, 32)        0
#
#  dropout (Dropout)           (None, 17, 17, 32)        0
#
#  flatten (Flatten)           (None, 9248)              0
#
#  dense (Dense)               (None, 256)               2367744
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 43)                11051
#
# =================================================================
# Total params: 2,379,691
# Trainable params: 2,379,691
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Train the model
model1 = cnn1.fit(X_train, y_train, batch_size=32, epochs=20, validation_data=(X_val, y_val))

warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# Epoch 1/20
# 981/981 [==============================] - 47s 47ms/step - loss: 1.1310 - accuracy: 0.6895 - val_loss: 0.3416 - val_accuracy: 0.9235
# Epoch 2/20
# 981/981 [==============================] - 49s 50ms/step - loss: 0.3562 - accuracy: 0.8991 - val_loss: 0.1971 - val_accuracy: 0.9558
# Epoch 3/20
# 981/981 [==============================] - 46s 47ms/step - loss: 0.2464 - accuracy: 0.9292 - val_loss: 0.1750 - val_accuracy: 0.9536
# Epoch 4/20
# 981/981 [==============================] - 50s 50ms/step - loss: 0.2010 - accuracy: 0.9418 - val_loss: 0.1243 - val_accuracy: 0.9712
# Epoch 5/20
# 981/981 [==============================] - 44s 45ms/step - loss: 0.1723 - accuracy: 0.9480 - val_loss: 0.1158 - val_accuracy: 0.9702
# Epoch 6/20
# 981/981 [==============================] - 43s 44ms/step - loss: 0.1574 - accuracy: 0.9524 - val_loss: 0.1161 - val_accuracy: 0.9707
# Epoch 7/20
# 981/981 [==============================] - 45s 46ms/step - loss: 0.1371 - accuracy: 0.9581 - val_loss: 0.0933 - val_accuracy: 0.9792
# Epoch 8/20
# 981/981 [==============================] - 43s 44ms/step - loss: 0.1278 - accuracy: 0.9609 - val_loss: 0.0881 - val_accuracy: 0.9793
# Epoch 9/20
# 981/981 [==============================] - 45s 46ms/step - loss: 0.1148 - accuracy: 0.9652 - val_loss: 0.0934 - val_accuracy: 0.9767
# Epoch 10/20
# 981/981 [==============================] - 43s 43ms/step - loss: 0.1131 - accuracy: 0.9647 - val_loss: 0.0847 - val_accuracy: 0.9795
# Epoch 11/20
# 981/981 [==============================] - 44s 45ms/step - loss: 0.1034 - accuracy: 0.9676 - val_loss: 0.0820 - val_accuracy: 0.9823
# Epoch 12/20
# 981/981 [==============================] - 43s 44ms/step - loss: 0.0939 - accuracy: 0.9696 - val_loss: 0.0808 - val_accuracy: 0.9832
# Epoch 13/20
# 981/981 [==============================] - 43s 44ms/step - loss: 0.0976 - accuracy: 0.9700 - val_loss: 0.0862 - val_accuracy: 0.9834
# Epoch 14/20
# 981/981 [==============================] - 42s 43ms/step - loss: 0.0933 - accuracy: 0.9719 - val_loss: 0.0857 - val_accuracy: 0.9827
# Epoch 15/20
# 981/981 [==============================] - 44s 44ms/step - loss: 0.0838 - accuracy: 0.9734 - val_loss: 0.1063 - val_accuracy: 0.9759
# Epoch 16/20
# 981/981 [==============================] - 43s 44ms/step - loss: 0.0817 - accuracy: 0.9745 - val_loss: 0.0770 - val_accuracy: 0.9832
# Epoch 17/20
# 981/981 [==============================] - 44s 45ms/step - loss: 0.0795 - accuracy: 0.9751 - val_loss: 0.0793 - val_accuracy: 0.9834
# Epoch 18/20
# 981/981 [==============================] - 50s 51ms/step - loss: 0.0751 - accuracy: 0.9769 - val_loss: 0.0721 - val_accuracy: 0.9842
# Epoch 19/20
# 981/981 [==============================] - 58s 59ms/step - loss: 0.0774 - accuracy: 0.9765 - val_loss: 0.0760 - val_accuracy: 0.9848
# Epoch 20/20
# 981/981 [==============================] - 51s 52ms/step - loss: 0.0755 - accuracy: 0.9776 - val_loss: 0.0732 - val_accuracy: 0.9861

# %% [markdown]
# ##### Plot Model Evolution

# %%
#plotting graphs for accuracy 
plt.figure(0)
plt.plot(model1.history['accuracy'], label='training accuracy')
plt.plot(model1.history['val_accuracy'], label='val accuracy')
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
#plotting graphs for loss 
plt.figure(1)
plt.plot(model1.history['loss'], label='training loss')
plt.plot(model1.history['val_loss'], label='val loss')
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
pd.DataFrame(model1.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %%
# Model1 confusion matrix
y_pred = cnn1.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis = 1)
y_true = np.argmax(y_test, axis = 1)
cm = confusion_matrix(y_true, y_pred_classes)


# Plot confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=False, fmt='d')
plt.title('Confusion Matrix for CNN1')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# Accuracy by class
diagonal = np.diag(cm)
# Use the percentage of correct predictions
diagonal = diagonal/cm.sum(axis=1)*100
plt.bar(range(len(diagonal)), diagonal)
plt.xlabel('Class')
plt.ylabel('Number of correct predictions')
plt.title('Accuracy by class for CNN1')
plt.show()

# Classification report
print(classification_report(y_true, y_pred_classes))
# Out:
# 395/395 [==============================] - 4s 10ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      0.72      0.83        60
#            1       0.96      0.95      0.96       720
#            2       0.95      0.95      0.95       750
#            3       0.90      0.93      0.91       450
#            4       0.95      0.95      0.95       660
#            5       0.85      0.93      0.89       630
#            6       1.00      0.72      0.84       150
#            7       0.97      0.82      0.89       450
#            8       0.92      0.89      0.91       450
#            9       0.92      0.96      0.94       480
#           10       0.98      0.97      0.97       660
#           11       0.89      0.92      0.91       420
#           12       1.00      0.92      0.96       690
#           13       0.99      0.98      0.98       720
#           14       1.00      1.00      1.00       270
#           15       0.75      1.00      0.86       210
#           16       1.00      0.97      0.98       150
#           17       0.99      0.91      0.95       360
#           18       0.95      0.92      0.93       390
#           19       0.81      0.98      0.89        60
#           20       0.78      0.92      0.84        90
#           21       0.96      0.80      0.87        90
#           22       0.80      0.96      0.87       120
#           23       0.76      0.96      0.85       150
#           24       0.98      0.72      0.83        90
#           25       0.92      0.93      0.92       480
#           26       0.93      0.78      0.85       180
#           27       0.91      0.48      0.63        60
#           28       0.96      0.82      0.88       150
#           29       0.60      0.96      0.74        90
#           30       0.93      0.56      0.70       150
#           31       0.89      0.93      0.91       270
#           32       0.83      1.00      0.91        60
#           33       1.00      0.97      0.98       210
#           34       1.00      0.96      0.98       120
#           35       0.98      0.96      0.97       390
#           36       0.95      0.93      0.94       120
#           37       1.00      0.93      0.97        60
#           38       0.84      1.00      0.91       690
#           39       0.97      0.96      0.96        90
#           40       0.97      0.94      0.96        90
#           41       1.00      0.67      0.80        60
#           42       0.92      0.99      0.95        90
#
#     accuracy                           0.93     12630
#    macro avg       0.92      0.90      0.90     12630
# weighted avg       0.93      0.93      0.93     12630

# %%
# Sum the quantity of correct predictions
correct_predictinons = sum(np.diag(cm))
# Sum the quantity of incorrect predictions
total_predictions = sum(sum(cm))

# Accuracy
accuracy = correct_predictinons/total_predictions

# Save wrong predictions into a variable for further analysis
wrong_predictions = np.where(y_pred_classes != y_true)[0]

# %% [markdown]
# ##### Test trained model

# %%
score_1 = cnn1.evaluate(X_test, y_test, verbose=0)

print('Test Score:', score_1[0])
print('Test Accuracy:', score_1[1])
# Out:
# Test Score: 0.4470148980617523
# Test Accuracy: 0.9258907437324524

# %%
# Save the model
cnn1.save('trained_models/cnn1_' + str(int(score_1[1]*100)) + '.h5')

# %% [markdown]
# #### CNN with 3 Convolutional Layer

# %%
def CNN3(input_shape):
    X_input = Input(input_shape)

    X = ZeroPadding2D((3, 3))(X_input)

    # BLOCK 1: CONV -> RELU -> MAXP -> DROPOUT
    X = Conv2D(32, kernel_size=(3, 3), activation='relu', strides = (1, 1), name = 'conv0')(X)
    X = MaxPooling2D(pool_size=(2, 2))(X)
    X = Dropout(0.25)(X)

    # BLOCK 2: CONV -> RELU -> MAXP -> DROPOUT
    X = Conv2D(64, kernel_size=(3, 3), activation='relu', strides = (1, 1), name = 'conv1')(X)
    X = MaxPooling2D(pool_size=(2, 2))(X)
    X = Dropout(0.25)(X)

    # BLOCK 3: CONV -> RELU -> MAXP -> DROPOUT
    X = Conv2D(128, kernel_size=(3, 3), activation='relu', strides = (1, 1), name = 'conv2')(X)
    X = MaxPooling2D(pool_size=(2, 2))(X)
    X = Dropout(0.4)(X)

    # FLATTEN X (means convert it to a vector) + FULLYCONNECTED
    X = Flatten()(X)
    X = Dense(256, activation='relu')(X)
    X = Dropout(0.3)(X)
    X = Dense(43, activation='softmax')(X)

    # Create model.
    model = Model(inputs = X_input, outputs = X, name='CNN1')

    return model

# %%
# Create the model
cnn3 = CNN3(X_train.shape[1:])

# Compile model
cnn3.compile(optimizer = "adam", loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# CNN model summary

cnn3.summary()
# Out:
# Model: "CNN1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 30, 30, 3)]       0
#
#  zero_padding2d_1 (ZeroPaddi  (None, 36, 36, 3)        0
#  ng2D)
#
#  conv0 (Conv2D)              (None, 34, 34, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 17, 17, 32)       0
#  )
#
#  dropout_2 (Dropout)         (None, 17, 17, 32)        0
#
#  conv1 (Conv2D)              (None, 15, 15, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  dropout_3 (Dropout)         (None, 7, 7, 64)          0
#
#  conv2 (Conv2D)              (None, 5, 5, 128)         73856
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 128)        0
#  2D)
#
#  dropout_4 (Dropout)         (None, 2, 2, 128)         0
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 43)                11051
#
# =================================================================
# Total params: 235,627
# Trainable params: 235,627
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Train the model
model3 = cnn3.fit(X_train, y_train, batch_size=32, epochs=20, validation_data=(X_val, y_val))

warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# Epoch 1/20
# 981/981 [==============================] - 49s 47ms/step - loss: 1.6783 - accuracy: 0.5051 - val_loss: 0.2988 - val_accuracy: 0.9133
# Epoch 2/20
# 981/981 [==============================] - 45s 46ms/step - loss: 0.3539 - accuracy: 0.8896 - val_loss: 0.0912 - val_accuracy: 0.9769
# Epoch 3/20
# 981/981 [==============================] - 46s 47ms/step - loss: 0.1921 - accuracy: 0.9398 - val_loss: 0.0472 - val_accuracy: 0.9885
# Epoch 4/20
# 981/981 [==============================] - 44s 45ms/step - loss: 0.1371 - accuracy: 0.9585 - val_loss: 0.0403 - val_accuracy: 0.9893
# Epoch 5/20
# 981/981 [==============================] - 47s 48ms/step - loss: 0.1191 - accuracy: 0.9643 - val_loss: 0.0293 - val_accuracy: 0.9921
# Epoch 6/20
# 981/981 [==============================] - 49s 50ms/step - loss: 0.0981 - accuracy: 0.9689 - val_loss: 0.0233 - val_accuracy: 0.9938
# Epoch 7/20
# 981/981 [==============================] - 51s 52ms/step - loss: 0.0928 - accuracy: 0.9719 - val_loss: 0.0216 - val_accuracy: 0.9949
# Epoch 8/20
# 981/981 [==============================] - 47s 48ms/step - loss: 0.0783 - accuracy: 0.9760 - val_loss: 0.0270 - val_accuracy: 0.9927
# Epoch 9/20
# 981/981 [==============================] - 50s 51ms/step - loss: 0.0788 - accuracy: 0.9760 - val_loss: 0.0198 - val_accuracy: 0.9944
# Epoch 10/20
# 981/981 [==============================] - 51s 52ms/step - loss: 0.0725 - accuracy: 0.9779 - val_loss: 0.0194 - val_accuracy: 0.9948
# Epoch 11/20
# 981/981 [==============================] - 48s 49ms/step - loss: 0.0688 - accuracy: 0.9788 - val_loss: 0.0136 - val_accuracy: 0.9967
# Epoch 12/20
# 981/981 [==============================] - 47s 48ms/step - loss: 0.0659 - accuracy: 0.9803 - val_loss: 0.0154 - val_accuracy: 0.9953
# Epoch 13/20
# 981/981 [==============================] - 43s 44ms/step - loss: 0.0615 - accuracy: 0.9817 - val_loss: 0.0153 - val_accuracy: 0.9962
# Epoch 14/20
# 981/981 [==============================] - 41s 42ms/step - loss: 0.0614 - accuracy: 0.9809 - val_loss: 0.0172 - val_accuracy: 0.9958
# Epoch 15/20
# 981/981 [==============================] - 43s 44ms/step - loss: 0.0584 - accuracy: 0.9830 - val_loss: 0.0179 - val_accuracy: 0.9941
# Epoch 16/20
# 981/981 [==============================] - 43s 44ms/step - loss: 0.0592 - accuracy: 0.9822 - val_loss: 0.0157 - val_accuracy: 0.9958
# Epoch 17/20
# 981/981 [==============================] - 42s 42ms/step - loss: 0.0583 - accuracy: 0.9821 - val_loss: 0.0175 - val_accuracy: 0.9960
# Epoch 18/20
# 981/981 [==============================] - 41s 42ms/step - loss: 0.0590 - accuracy: 0.9833 - val_loss: 0.0123 - val_accuracy: 0.9972
# Epoch 19/20
# 981/981 [==============================] - 43s 43ms/step - loss: 0.0565 - accuracy: 0.9832 - val_loss: 0.0161 - val_accuracy: 0.9950
# Epoch 20/20
# 981/981 [==============================] - 41s 42ms/step - loss: 0.0542 - accuracy: 0.9848 - val_loss: 0.0157 - val_accuracy: 0.9969

# %%
#plotting graphs for accuracy 
plt.figure(0)
plt.plot(model3.history['accuracy'], label='training accuracy')
plt.plot(model3.history['val_accuracy'], label='val accuracy')
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
#plotting graphs for loss 
plt.figure(1)
plt.plot(model3.history['loss'], label='training loss')
plt.plot(model3.history['val_loss'], label='val loss')
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
pd.DataFrame(model3.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %% [markdown]
# ##### Test trained model

# %%
score_3 = cnn3.evaluate(X_test, y_test, verbose=0)

print('Test Score:', score_3[0])
print('Test Accuracy:', score_3[1])
# Out:
# Test Score: 0.1209736093878746
# Test Accuracy: 0.9753760695457458

# %%
# Save the model
cnn3.save('trained_models/cnn3_' + str(int(score_3[1]*100)) + '.h5')

# %%
# Model3 confusion matrix
y_pred = cnn3.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis = 1)
y_true = np.argmax(y_test, axis = 1)
cm_3 = confusion_matrix(y_true, y_pred_classes)

# Plot confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm_3, annot=False, fmt='d')
plt.title('Confusion Matrix for CNN3')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# Accuracy by class
diagonal = np.diag(cm_3)
# Use the percentage of correct predictions
diagonal = np.diag(cm_3)/cm_3.sum(axis=1)*100
plt.bar(range(len(diagonal)), diagonal)
plt.xlabel('Class')
plt.ylabel('Number of correct predictions')
plt.title('Accuracy by class for CNN3')
plt.show()

# Classification report
print(classification_report(y_true, y_pred_classes))
# Out:
# 395/395 [==============================] - 5s 11ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        60
#            1       0.98      1.00      0.99       720
#            2       1.00      0.98      0.99       750
#            3       0.99      0.98      0.98       450
#            4       1.00      0.99      0.99       660
#            5       0.96      0.99      0.97       630
#            6       1.00      0.90      0.95       150
#            7       0.98      0.99      0.99       450
#            8       0.98      0.98      0.98       450
#            9       0.93      0.99      0.96       480
#           10       1.00      0.99      0.99       660
#           11       0.96      0.99      0.98       420
#           12       1.00      0.96      0.98       690
#           13       1.00      1.00      1.00       720
#           14       0.99      1.00      1.00       270
#           15       0.99      1.00      0.99       210
#           16       1.00      0.99      0.99       150
#           17       1.00      1.00      1.00       360
#           18       1.00      0.92      0.96       390
#           19       1.00      1.00      1.00        60
#           20       0.88      1.00      0.94        90
#           21       0.87      0.94      0.90        90
#           22       1.00      0.79      0.88       120
#           23       0.92      1.00      0.96       150
#           24       1.00      0.93      0.97        90
#           25       0.97      0.98      0.97       480
#           26       0.90      0.98      0.94       180
#           27       0.94      0.50      0.65        60
#           28       0.98      0.97      0.97       150
#           29       0.75      1.00      0.86        90
#           30       0.93      0.83      0.88       150
#           31       0.99      0.99      0.99       270
#           32       1.00      1.00      1.00        60
#           33       0.99      1.00      1.00       210
#           34       1.00      0.98      0.99       120
#           35       0.99      1.00      0.99       390
#           36       1.00      0.91      0.95       120
#           37       1.00      1.00      1.00        60
#           38       0.96      1.00      0.98       690
#           39       0.99      0.96      0.97        90
#           40       0.88      0.98      0.93        90
#           41       1.00      0.47      0.64        60
#           42       0.88      0.99      0.93        90
#
#     accuracy                           0.98     12630
#    macro avg       0.97      0.95      0.95     12630
# weighted avg       0.98      0.98      0.97     12630

# %%
# Sum the quantity of correct predictions
correct_predictinons = sum(np.diag(cm_3))
# Sum the quantity of incorrect predictions
total_predictions = sum(sum(cm_3))

# Accuracy
accuracy = correct_predictinons/total_predictions

# Save wrong predictions into a variable for further analysis
wrong_predictions_3 = np.where(y_pred_classes != y_true)[0]

# %% [markdown]
# ##### Time to predict

# %%
x_sample = X_test[0].reshape(1, X_test[0].shape[0], X_test[0].shape[0], X_test[1].shape[2])
y_sample = y_test[0]

x_sample.shape

#Start timer
import time
start = time.time()
sample_pred = cnn3.predict(x_sample)
end = time.time()

# Check prediction
print("Predicted class:", np.argmax(sample_pred))
print("Actual class:", np.argmax(y_sample))

# Print time elapsed
print("Time to predict:", end - start, "seconds")
# Out:
# 1/1 [==============================] - 0s 33ms/step
# Predicted class: 16
# Actual class: 16
# Time to predict: 0.09305143356323242 seconds

# %% [markdown]
# #### CNN with 3 Convolutional Layer using BatchNormalization

# %%
def CNN3_2(input_shape):
    X_input = Input(input_shape)

    X = ZeroPadding2D((3, 3))(X_input)

    # BLOCK 1: CONV -> RELU -> MAXP -> DROPOUT
    X = Conv2D(32, kernel_size=(3, 3), activation='relu', strides = (1, 1), name = 'conv0')(X)
    X = BatchNormalization()(X)
    X = MaxPooling2D(pool_size=(2, 2))(X)

    # BLOCK 2: CONV -> RELU -> MAXP -> DROPOUT
    X = Conv2D(64, kernel_size=(3, 3), activation='relu', strides = (1, 1), name = 'conv1')(X)
    X = BatchNormalization()(X)
    X = MaxPooling2D(pool_size=(2, 2))(X)

    # BLOCK 3: CONV -> RELU -> MAXP -> DROPOUT
    X = Conv2D(128, kernel_size=(3, 3), activation='relu', strides = (1, 1), name = 'conv2')(X)
    X = BatchNormalization()(X)
    X = MaxPooling2D(pool_size=(2, 2))(X)

    # FLATTEN X (means convert it to a vector) + FULLYCONNECTED
    X = Flatten()(X)
    X = Dense(256, activation='relu')(X)
    X = BatchNormalization()(X)
    X = Dense(43, activation='softmax')(X)

    # Create model.
    model = Model(inputs = X_input, outputs = X, name='CNN1')

    return model

# %%
# Create the model
cnn3_2 = CNN3_2(X_train.shape[1:])

# Compile model
cnn3_2.compile(optimizer = "adam", loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# CNN model summary

cnn3_2.summary()
# Out:
# Model: "CNN1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 30, 30, 3)]       0
#
#  zero_padding2d_2 (ZeroPaddi  (None, 36, 36, 3)        0
#  ng2D)
#
#  conv0 (Conv2D)              (None, 34, 34, 32)        896
#
#  batch_normalization (BatchN  (None, 34, 34, 32)       128
#  ormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 17, 17, 32)       0
#  2D)
#
#  conv1 (Conv2D)              (None, 15, 15, 64)        18496
#
#  batch_normalization_1 (Batc  (None, 15, 15, 64)       256
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  conv2 (Conv2D)              (None, 5, 5, 128)         73856
#
#  batch_normalization_2 (Batc  (None, 5, 5, 128)        512
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 2, 2, 128)        0
#  2D)
#
#  flatten_2 (Flatten)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 256)               131328
#
#  batch_normalization_3 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_5 (Dense)             (None, 43)                11051
#
# =================================================================
# Total params: 237,547
# Trainable params: 236,587
# Non-trainable params: 960
# _________________________________________________________________

# %%
#Train the model
model3_2 = cnn3_2.fit(X_train, y_train, batch_size=32, epochs=20, validation_data=(X_val, y_val))

warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# Epoch 1/20
# 981/981 [==============================] - 50s 49ms/step - loss: 0.3164 - accuracy: 0.9187 - val_loss: 0.0860 - val_accuracy: 0.9765
# Epoch 2/20
# 981/981 [==============================] - 48s 49ms/step - loss: 0.0386 - accuracy: 0.9900 - val_loss: 0.1411 - val_accuracy: 0.9586
# Epoch 3/20
# 981/981 [==============================] - 50s 51ms/step - loss: 0.0271 - accuracy: 0.9929 - val_loss: 0.0287 - val_accuracy: 0.9913
# Epoch 4/20
# 981/981 [==============================] - 50s 51ms/step - loss: 0.0245 - accuracy: 0.9931 - val_loss: 0.0738 - val_accuracy: 0.9792
# Epoch 5/20
# 981/981 [==============================] - 49s 50ms/step - loss: 0.0193 - accuracy: 0.9937 - val_loss: 0.1517 - val_accuracy: 0.9713
# Epoch 6/20
# 981/981 [==============================] - 47s 48ms/step - loss: 0.0151 - accuracy: 0.9957 - val_loss: 0.0322 - val_accuracy: 0.9912
# Epoch 7/20
# 981/981 [==============================] - 47s 48ms/step - loss: 0.0171 - accuracy: 0.9945 - val_loss: 0.0201 - val_accuracy: 0.9944
# Epoch 8/20
# 981/981 [==============================] - 51s 52ms/step - loss: 0.0070 - accuracy: 0.9977 - val_loss: 0.0352 - val_accuracy: 0.9903
# Epoch 9/20
# 981/981 [==============================] - 50s 51ms/step - loss: 0.0161 - accuracy: 0.9953 - val_loss: 0.0270 - val_accuracy: 0.9935
# Epoch 10/20
# 981/981 [==============================] - 49s 50ms/step - loss: 0.0071 - accuracy: 0.9981 - val_loss: 0.0189 - val_accuracy: 0.9948
# Epoch 11/20
# 981/981 [==============================] - 50s 51ms/step - loss: 0.0127 - accuracy: 0.9962 - val_loss: 0.0502 - val_accuracy: 0.9878
# Epoch 12/20
# 981/981 [==============================] - 51s 52ms/step - loss: 0.0074 - accuracy: 0.9978 - val_loss: 0.0249 - val_accuracy: 0.9941
# Epoch 13/20
# 981/981 [==============================] - 57s 58ms/step - loss: 0.0072 - accuracy: 0.9978 - val_loss: 0.0394 - val_accuracy: 0.9906
# Epoch 14/20
# 981/981 [==============================] - 58s 60ms/step - loss: 0.0073 - accuracy: 0.9978 - val_loss: 0.0577 - val_accuracy: 0.9901
# Epoch 15/20
# 981/981 [==============================] - 58s 59ms/step - loss: 0.0063 - accuracy: 0.9984 - val_loss: 0.0500 - val_accuracy: 0.9880
# Epoch 16/20
# 981/981 [==============================] - 58s 59ms/step - loss: 0.0084 - accuracy: 0.9974 - val_loss: 0.0202 - val_accuracy: 0.9954
# Epoch 17/20
# 981/981 [==============================] - 57s 58ms/step - loss: 0.0068 - accuracy: 0.9982 - val_loss: 0.0481 - val_accuracy: 0.9887
# Epoch 18/20
# 981/981 [==============================] - 60s 61ms/step - loss: 0.0072 - accuracy: 0.9980 - val_loss: 0.0435 - val_accuracy: 0.9895
# Epoch 19/20
# 981/981 [==============================] - 59s 60ms/step - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.0248 - val_accuracy: 0.9963
# Epoch 20/20
# 981/981 [==============================] - 55s 56ms/step - loss: 0.0039 - accuracy: 0.9987 - val_loss: 0.0422 - val_accuracy: 0.9892

# %%
#plotting graphs for accuracy 
plt.figure(0)
plt.plot(model3_2.history['accuracy'], label='training accuracy')
plt.plot(model3_2.history['val_accuracy'], label='val accuracy')
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
#plotting graphs for loss 
plt.figure(1)
plt.plot(model3_2.history['loss'], label='training loss')
plt.plot(model3_2.history['val_loss'], label='val loss')
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
pd.DataFrame(model3_2.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %% [markdown]
# ##### Test trained model

# %%
score_3_2 = cnn3_2.evaluate(X_test, y_test, verbose=0)

print('Test Score:', score_3_2[0])
print('Test Accuracy:', score_3_2[1])
# Out:
# Test Score: 0.2287306785583496
# Test Accuracy: 0.9501187801361084

# %%
# Save the model
cnn3_2.save('trained_models/cnn3_2_' + str(int(score_3_2[1]*100)) + '.h5')

# %%
# Model3 confusion matrix
y_pred = cnn3_2.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis = 1)
y_true = np.argmax(y_test, axis = 1)
cm_3_2 = confusion_matrix(y_true, y_pred_classes)

# Plot confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm_3_2, annot=False, fmt='d')
plt.title('Confusion Matrix for CNN3')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# Accuracy by class
diagonal = np.diag(cm_3_2)
# Use the percentage of correct predictions
diagonal = diagonal/cm_3_2.sum(axis=1)*100
plt.bar(range(len(diagonal)), diagonal)
plt.xlabel('Class')
plt.ylabel('Number of correct predictions')
plt.title('Accuracy by class for CNN3')
plt.show()

# Classification report
print(classification_report(y_true, y_pred_classes))
# Out:
# 395/395 [==============================] - 7s 17ms/step
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93        60
#            1       0.99      0.99      0.99       720
#            2       0.94      0.99      0.97       750
#            3       0.95      0.97      0.96       450
#            4       0.93      1.00      0.96       660
#            5       0.93      0.99      0.96       630
#            6       1.00      0.83      0.91       150
#            7       1.00      0.91      0.95       450
#            8       0.96      0.95      0.96       450
#            9       0.95      1.00      0.98       480
#           10       1.00      0.97      0.99       660
#           11       0.98      0.99      0.98       420
#           12       1.00      0.90      0.95       690
#           13       1.00      0.99      0.99       720
#           14       1.00      1.00      1.00       270
#           15       0.98      0.90      0.94       210
#           16       1.00      0.99      0.99       150
#           17       1.00      1.00      1.00       360
#           18       0.99      0.80      0.88       390
#           19       0.70      1.00      0.82        60
#           20       0.80      0.98      0.88        90
#           21       0.75      0.98      0.85        90
#           22       0.99      0.78      0.87       120
#           23       0.89      0.85      0.87       150
#           24       0.98      0.88      0.92        90
#           25       0.99      0.98      0.99       480
#           26       0.93      0.84      0.88       180
#           27       0.83      0.50      0.62        60
#           28       0.97      0.93      0.95       150
#           29       0.82      0.99      0.90        90
#           30       0.99      0.71      0.83       150
#           31       0.97      0.99      0.98       270
#           32       0.86      0.52      0.65        60
#           33       0.98      0.99      0.98       210
#           34       0.96      0.98      0.97       120
#           35       0.96      0.99      0.97       390
#           36       0.99      0.87      0.92       120
#           37       0.92      0.93      0.93        60
#           38       0.97      0.98      0.97       690
#           39       0.88      0.63      0.74        90
#           40       0.35      1.00      0.52        90
#           41       1.00      0.78      0.88        60
#           42       1.00      1.00      1.00        90
#
#     accuracy                           0.95     12630
#    macro avg       0.93      0.91      0.91     12630
# weighted avg       0.96      0.95      0.95     12630

# %%
# Sum the quantity of correct predictions
correct_predictinons = sum(np.diag(cm_3_2))
# Sum the quantity of incorrect predictions
total_predictions = sum(sum(cm_3_2))

# Accuracy
accuracy = correct_predictinons/total_predictions

# Save wrong predictions into a variable for further analysis
wrong_predictions_3_2 = np.where(y_pred_classes != y_true)[0]

# %% [markdown]
# #### CNN with 3 Convolutional Layer using BatchNormalization and Dropdown

# %%
def CNN3_3(input_shape):
    X_input = Input(input_shape)

    X = ZeroPadding2D((3, 3))(X_input)

    # BLOCK 1: CONV -> RELU -> MAXP -> DROPOUT
    X = Conv2D(32, kernel_size=(3, 3), activation='relu', strides = (1, 1), name = 'conv0')(X)
    X = BatchNormalization()(X)
    X = MaxPooling2D(pool_size=(2, 2))(X)
    X = Dropout(0.5)(X)

    # BLOCK 2: CONV -> RELU -> MAXP -> DROPOUT
    X = Conv2D(64, kernel_size=(3, 3), activation='relu', strides = (1, 1), name = 'conv1')(X)
    X = BatchNormalization()(X)
    X = MaxPooling2D(pool_size=(2, 2))(X)
    X = Dropout(0.5)(X)

    # BLOCK 3: CONV -> RELU -> MAXP -> DROPOUT
    X = Conv2D(128, kernel_size=(3, 3), activation='relu', strides = (1, 1), name = 'conv2')(X)
    X = BatchNormalization()(X)
    X = MaxPooling2D(pool_size=(2, 2))(X)
    X = Dropout(0.5)(X)

    # FLATTEN X (means convert it to a vector) + FULLYCONNECTED
    X = Flatten()(X)
    X = Dense(256, activation='relu')(X)
    X = BatchNormalization()(X)
    X = Dense(43, activation='softmax')(X)

    # Create model.
    model = Model(inputs = X_input, outputs = X, name='CNN1')

    return model

# %%
# Create the model
cnn3_3 = CNN3_3(X_train.shape[1:])

# Compile model
cnn3_3.compile(optimizer = "adam", loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# CNN model summary

cnn3_3.summary()
# Out:
# Model: "CNN1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 30, 30, 3)]       0
#
#  zero_padding2d (ZeroPadding  (None, 36, 36, 3)        0
#  2D)
#
#  conv0 (Conv2D)              (None, 34, 34, 32)        896
#
#  batch_normalization (BatchN  (None, 34, 34, 32)       128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 17, 17, 32)       0
#  )
#
#  dropout (Dropout)           (None, 17, 17, 32)        0
#
#  conv1 (Conv2D)              (None, 15, 15, 64)        18496
#
#  batch_normalization_1 (Batc  (None, 15, 15, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 7, 7, 64)          0
#
#  conv2 (Conv2D)              (None, 5, 5, 128)         73856
#
#  batch_normalization_2 (Batc  (None, 5, 5, 128)        512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 2, 2, 128)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 256)               131328
#
#  batch_normalization_3 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_1 (Dense)             (None, 43)                11051
#
# =================================================================
# Total params: 237,547
# Trainable params: 236,587
# Non-trainable params: 960
# _________________________________________________________________

# %%
#Train the model
model3_3 = cnn3_3.fit(X_train, y_train, batch_size=32, epochs=20, validation_data=(X_val, y_val))

warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# Epoch 1/20
# 981/981 [==============================] - 84s 83ms/step - loss: 1.4057 - accuracy: 0.6096 - val_loss: 0.1976 - val_accuracy: 0.9429
# Epoch 2/20
# 981/981 [==============================] - 95s 97ms/step - loss: 0.3277 - accuracy: 0.8984 - val_loss: 0.0841 - val_accuracy: 0.9763
# Epoch 3/20
# 981/981 [==============================] - 90s 92ms/step - loss: 0.2095 - accuracy: 0.9345 - val_loss: 0.0619 - val_accuracy: 0.9841
# Epoch 4/20
# 981/981 [==============================] - 84s 86ms/step - loss: 0.1656 - accuracy: 0.9488 - val_loss: 0.0395 - val_accuracy: 0.9897
# Epoch 5/20
# 981/981 [==============================] - 72s 73ms/step - loss: 0.1444 - accuracy: 0.9551 - val_loss: 0.0351 - val_accuracy: 0.9906
# Epoch 6/20
# 981/981 [==============================] - 72s 74ms/step - loss: 0.1220 - accuracy: 0.9616 - val_loss: 0.0360 - val_accuracy: 0.9893
# Epoch 7/20
# 981/981 [==============================] - 73s 75ms/step - loss: 0.1060 - accuracy: 0.9662 - val_loss: 0.0274 - val_accuracy: 0.9934
# Epoch 8/20
# 981/981 [==============================] - 67s 69ms/step - loss: 0.1046 - accuracy: 0.9660 - val_loss: 0.0303 - val_accuracy: 0.9931
# Epoch 9/20
# 981/981 [==============================] - 62s 63ms/step - loss: 0.0899 - accuracy: 0.9712 - val_loss: 0.0260 - val_accuracy: 0.9926
# Epoch 10/20
# 981/981 [==============================] - 59s 60ms/step - loss: 0.0860 - accuracy: 0.9741 - val_loss: 0.0249 - val_accuracy: 0.9936
# Epoch 11/20
# 981/981 [==============================] - 60s 61ms/step - loss: 0.0817 - accuracy: 0.9732 - val_loss: 0.0222 - val_accuracy: 0.9938
# Epoch 12/20
# 981/981 [==============================] - 61s 62ms/step - loss: 0.0803 - accuracy: 0.9744 - val_loss: 0.0206 - val_accuracy: 0.9949
# Epoch 13/20
# 981/981 [==============================] - 61s 62ms/step - loss: 0.0723 - accuracy: 0.9770 - val_loss: 0.0243 - val_accuracy: 0.9939
# Epoch 14/20
# 981/981 [==============================] - 59s 60ms/step - loss: 0.0730 - accuracy: 0.9770 - val_loss: 0.0222 - val_accuracy: 0.9935
# Epoch 15/20
# 981/981 [==============================] - 60s 61ms/step - loss: 0.0675 - accuracy: 0.9784 - val_loss: 0.0166 - val_accuracy: 0.9960
# Epoch 16/20
# 981/981 [==============================] - 57s 58ms/step - loss: 0.0614 - accuracy: 0.9795 - val_loss: 0.0187 - val_accuracy: 0.9952
# Epoch 17/20
# 981/981 [==============================] - 57s 59ms/step - loss: 0.0591 - accuracy: 0.9809 - val_loss: 0.0240 - val_accuracy: 0.9943
# Epoch 18/20
# 981/981 [==============================] - 62s 63ms/step - loss: 0.0625 - accuracy: 0.9808 - val_loss: 0.0161 - val_accuracy: 0.9959
# Epoch 19/20
# 981/981 [==============================] - 60s 62ms/step - loss: 0.0553 - accuracy: 0.9824 - val_loss: 0.0155 - val_accuracy: 0.9955
# Epoch 20/20
# 981/981 [==============================] - 59s 60ms/step - loss: 0.0517 - accuracy: 0.9833 - val_loss: 0.0139 - val_accuracy: 0.9971

# %%
#plotting graphs for accuracy 
plt.figure(0)
plt.plot(model3_3.history['accuracy'], label='training accuracy')
plt.plot(model3_3.history['val_accuracy'], label='val accuracy')
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
#plotting graphs for loss 
plt.figure(1)
plt.plot(model3_3.history['loss'], label='training loss')
plt.plot(model3_3.history['val_loss'], label='val loss')
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
pd.DataFrame(model3_3.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %% [markdown]
# ##### Test trained model

# %%
score_3_3 = cnn3_3.evaluate(X_test, y_test, verbose=0)

print('Test Score:', score_3_3[0])
print('Test Accuracy:', score_3_3[1])
# Out:
# Test Score: 0.0970827117562294
# Test Accuracy: 0.976642906665802

# %%
# Save the model
cnn3_3.save('trained_models/cnn3_3_' + str(int(score_3_3[1]*100)) + '.h5')

# %%
# Model3 confusion matrix
y_pred = cnn3_3.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis = 1)
y_true = np.argmax(y_test, axis = 1)
cm_3_3 = confusion_matrix(y_true, y_pred_classes)

# Plot confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm_3_3, annot=False, fmt='d')
plt.title('Confusion Matrix for CNN3')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# Accuracy by class
diagonal = np.diag(cm_3_3)
# Use the percentage of correct predictions
diagonal = diagonal/cm_3_3.sum(axis=1)*100
plt.bar(range(len(diagonal)), diagonal)
plt.xlabel('Class')
plt.ylabel('Number of correct predictions')
plt.title('Accuracy by class for CNN3')
plt.show()

# Classification report
print(classification_report(y_true, y_pred_classes))
# Out:
# 395/395 [==============================] - 8s 20ms/step
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        60
#            1       0.93      0.99      0.96       720
#            2       0.98      0.99      0.98       750
#            3       0.99      0.93      0.96       450
#            4       1.00      0.96      0.98       660
#            5       0.94      0.99      0.96       630
#            6       1.00      0.84      0.91       150
#            7       0.98      0.99      0.99       450
#            8       0.98      0.96      0.97       450
#            9       0.98      1.00      0.99       480
#           10       1.00      0.99      0.99       660
#           11       0.84      1.00      0.91       420
#           12       0.99      0.99      0.99       690
#           13       0.99      1.00      0.99       720
#           14       1.00      1.00      1.00       270
#           15       0.99      0.97      0.98       210
#           16       1.00      0.99      0.99       150
#           17       0.99      1.00      0.99       360
#           18       0.96      0.81      0.88       390
#           19       0.98      0.93      0.96        60
#           20       0.96      1.00      0.98        90
#           21       0.48      0.98      0.64        90
#           22       0.98      0.89      0.93       120
#           23       0.95      0.97      0.96       150
#           24       0.93      0.77      0.84        90
#           25       0.96      0.91      0.94       480
#           26       0.92      0.82      0.87       180
#           27       0.88      0.37      0.52        60
#           28       0.92      0.99      0.95       150
#           29       0.87      0.81      0.84        90
#           30       0.92      0.92      0.92       150
#           31       0.99      0.92      0.95       270
#           32       0.97      0.50      0.66        60
#           33       0.89      1.00      0.94       210
#           34       0.92      0.98      0.95       120
#           35       1.00      0.98      0.99       390
#           36       0.97      0.88      0.92       120
#           37       0.94      1.00      0.97        60
#           38       0.97      0.99      0.98       690
#           39       0.98      0.72      0.83        90
#           40       1.00      0.93      0.97        90
#           41       0.83      0.88      0.85        60
#           42       0.90      0.93      0.92        90
#
#     accuracy                           0.96     12630
#    macro avg       0.94      0.92      0.92     12630
# weighted avg       0.96      0.96      0.96     12630

# %%
# Sum the quantity of correct predictions
correct_predictinons = sum(np.diag(cm_3_3))
# Sum the quantity of incorrect predictions
total_predictions = sum(sum(cm_3_3))

# Accuracy
accuracy = correct_predictinons/total_predictions

# Save wrong predictions into a variable for further analysis
wrong_predictions_3_3 = np.where(y_pred_classes != y_true)[0]

# %%
# Compare wrong predictions of each model
print('Wrong predictions for CNN3_1:', len(wrong_predictions_3))
print('Wrong predictions for CNN3_2:', len(wrong_predictions_3_2))
print('Wrong predictions for CNN3_3:', len(wrong_predictions_3_3))

# Print predictions the intersection of the three models
print('Intersection of the three models:', len(set(wrong_predictions_3) & set(wrong_predictions_3_2) & set(wrong_predictions_3_3)))
# Out:
# Wrong predictions for CNN3_1: 311
# Wrong predictions for CNN3_2: 630
# Wrong predictions for CNN3_3: 532
# Intersection of the three models: 122

# %% [markdown]
# #### Combination of the 4 alghorithms

# %%
x_sample = X_test[0].reshape(1, X_test[0].shape[0], X_test[0].shape[0], X_test[1].shape[2])
y_sample = y_test[0]

x_sample.shape

# Predict the class of the first image of the test set
start = time.time()
predicted1 = cnn1.predict(x_sample)
predicted3 = cnn3.predict(x_sample)
predicted3_2 = cnn3_2.predict(x_sample)
predicted3_3 = cnn3_3.predict(x_sample)

# Sum the probabilities of the three models
predicted_sum = predicted1 + predicted3 + predicted3_2 + predicted3_3

print("Time taken:", time.time() - start)

# Print the predicted class
print("Class with the highest probability:", np.argmax(predicted_sum))

# Print the real class
print("Real class:", np.argmax(y_sample))
# Out:
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# Time taken: 0.35817933082580566
# Class with the highest probability: 16
# Real class: 16

# %%
# The same as before but using the full test set
predicted1 = cnn1.predict(X_test)
predicted3 = cnn3.predict(X_test)
predicted3_2 = cnn3_2.predict(X_test)
predicted3_3 = cnn3_3.predict(X_test)

# Sum the probabilities of the three models
predicted_sum = predicted1 + predicted3 + predicted3_2 + predicted3_3

# Compare the predicted class with the real class
predicted_classes = np.argmax(predicted_sum, axis = 1)
real_classes = np.argmax(y_test, axis = 1)

# Print the accuracy
print("Accuracy:", sum(predicted_classes == real_classes)/len(real_classes))
# Out:
# 395/395 [==============================] - 3s 9ms/step
# 395/395 [==============================] - 4s 11ms/step
# 395/395 [==============================] - 6s 15ms/step
# 395/395 [==============================] - 6s 15ms/step
# Accuracy: 0.978701504354711

# %% [markdown]
# #### Combination of 2 best algorithms

# %%
x_sample = X_test[0].reshape(1, X_test[0].shape[0], X_test[0].shape[0], X_test[1].shape[2])
y_sample = y_test[0]

x_sample.shape

# Predict the class of the first image of the test set
start = time.time()
predicted3 = cnn3.predict(x_sample)
predicted3_2 = cnn3_2.predict(x_sample)

# Sum the probabilities of the three models
predicted_sum = predicted3 + predicted3_2

print("Time taken:", time.time() - start)

# Print the predicted class
print("Class with the highest probability:", np.argmax(predicted_sum))

# Print the real class
print("Real class:", np.argmax(y_sample))
# Out:
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# Time taken: 0.19300222396850586
# Class with the highest probability: 16
# Real class: 16

# %%
# The same as before but using the full test set
predicted3 = cnn3.predict(X_test)
predicted3_2 = cnn3_3.predict(X_test)

# Sum the probabilities of the three models
predicted_sum = predicted3 + predicted3_2

# Compare the predicted class with the real class
predicted_classes = np.argmax(predicted_sum, axis = 1)
real_classes = np.argmax(y_test, axis = 1)

# Print the accuracy
print("Accuracy:", sum(predicted_classes == real_classes)/len(real_classes))
# Out:
# 395/395 [==============================] - 5s 12ms/step
# 395/395 [==============================] - 4s 9ms/step
# Accuracy: 0.9712589073634205

# %% [markdown]
# #### CNN with 4 Convolutional Layer using BatchNormalization and Dropdown

# %%
def CNN4_1(input_shape):
    X_input = Input(input_shape)

    X = ZeroPadding2D((3, 3))(X_input)

    # BLOCK 1: CONV -> RELU -> MAXP -> DROPOUT
    X = Conv2D(32, kernel_size=(3, 3), activation='relu', strides = (1, 1), name = 'conv0')(X)
    X = BatchNormalization()(X)

    X = Conv2D(32, kernel_size=(3, 3), activation='relu', strides = (1, 1), name = 'conv1')(X)
    X = BatchNormalization()(X)
    X = MaxPooling2D(pool_size=(2, 2))(X)
    X = Dropout(0.25)(X)

    # BLOCK 2: CONV -> RELU -> MAXP -> DROPOUT
    X = Conv2D(64, kernel_size=(3, 3), activation='relu', strides = (1, 1), name = 'conv2')(X)
    X = BatchNormalization()(X)
    X = Dropout(0.25)(X)

    X = Conv2D(128, kernel_size=(3, 3), activation='relu', strides = (1, 1), name = 'conv3')(X)
    X = BatchNormalization()(X)
    X = MaxPooling2D(pool_size=(2, 2))(X)
    X = Dropout(0.25)(X)

    X = Flatten()(X)

    X = Dense(512, activation='relu')(X)
    X = BatchNormalization()(X)
    X = Dropout(0.5)(X)

    X = Dense(256, activation='relu')(X)
    X = BatchNormalization()(X)
    X = Dropout(0.5)(X)

    X = Dense(43, activation='softmax')(X)

    # Create model.
    model = Model(inputs = X_input, outputs = X, name='CNN1')

    return model

# %%
# Create the model
cnn4_1 = CNN4_1(X_train.shape[1:])

# Compile model
cnn4_1.compile(optimizer = "adam", loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# CNN model summary

cnn4_1.summary()
# Out:
# Model: "CNN1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 30, 30, 3)]       0
#
#  zero_padding2d_4 (ZeroPaddi  (None, 36, 36, 3)        0
#  ng2D)
#
#  conv0 (Conv2D)              (None, 34, 34, 32)        896
#
#  batch_normalization_8 (Batc  (None, 34, 34, 32)       128
#  hNormalization)
#
#  conv1 (Conv2D)              (None, 32, 32, 32)        9248
#
#  batch_normalization_9 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  max_pooling2d_9 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  dropout_6 (Dropout)         (None, 16, 16, 32)        0
#
#  conv2 (Conv2D)              (None, 14, 14, 64)        18496
#
#  batch_normalization_10 (Bat  (None, 14, 14, 64)       256
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 14, 14, 64)        0
#
#  conv3 (Conv2D)              (None, 12, 12, 128)       73856
#
#  batch_normalization_11 (Bat  (None, 12, 12, 128)      512
#  chNormalization)
#
#  max_pooling2d_10 (MaxPoolin  (None, 6, 6, 128)        0
#  g2D)
#
#  dropout_8 (Dropout)         (None, 6, 6, 128)         0
#
#  flatten_4 (Flatten)         (None, 4608)              0
#
#  dense_8 (Dense)             (None, 512)               2359808
#
#  batch_normalization_12 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dropout_9 (Dropout)         (None, 512)               0
#
#  dense_9 (Dense)             (None, 256)               131328
#
#  batch_normalization_13 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_10 (Dropout)        (None, 256)               0
#
#  dense_10 (Dense)            (None, 43)                11051
#
# =================================================================
# Total params: 2,608,779
# Trainable params: 2,606,731
# Non-trainable params: 2,048
# _________________________________________________________________

# %%
#Train the model
model4_1 = cnn4_1.fit(X_train, y_train, batch_size=32, epochs=20, validation_data=(X_val, y_val))

warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# Epoch 1/20
# 981/981 [==============================] - 158s 157ms/step - loss: 0.8436 - accuracy: 0.7735 - val_loss: 0.0697 - val_accuracy: 0.9820
# Epoch 2/20
# 981/981 [==============================] - 155s 158ms/step - loss: 0.1484 - accuracy: 0.9574 - val_loss: 0.0502 - val_accuracy: 0.9869
# Epoch 3/20
# 981/981 [==============================] - 156s 159ms/step - loss: 0.0893 - accuracy: 0.9747 - val_loss: 0.1625 - val_accuracy: 0.9638
# Epoch 4/20
# 981/981 [==============================] - 145s 148ms/step - loss: 0.0844 - accuracy: 0.9751 - val_loss: 0.0414 - val_accuracy: 0.9909
# Epoch 5/20
# 981/981 [==============================] - 149s 152ms/step - loss: 0.0628 - accuracy: 0.9828 - val_loss: 0.0463 - val_accuracy: 0.9911
# Epoch 6/20
# 981/981 [==============================] - 148s 151ms/step - loss: 0.0525 - accuracy: 0.9841 - val_loss: 0.0239 - val_accuracy: 0.9940
# Epoch 7/20
# 981/981 [==============================] - 148s 151ms/step - loss: 0.0449 - accuracy: 0.9864 - val_loss: 0.7209 - val_accuracy: 0.9485
# Epoch 8/20
# 981/981 [==============================] - 154s 157ms/step - loss: 0.0345 - accuracy: 0.9898 - val_loss: 0.0292 - val_accuracy: 0.9941
# Epoch 9/20
# 981/981 [==============================] - 148s 151ms/step - loss: 0.0316 - accuracy: 0.9901 - val_loss: 0.1092 - val_accuracy: 0.9839
# Epoch 10/20
# 981/981 [==============================] - 149s 152ms/step - loss: 0.0365 - accuracy: 0.9890 - val_loss: 0.0369 - val_accuracy: 0.9925
# Epoch 11/20
# 981/981 [==============================] - 149s 152ms/step - loss: 0.0293 - accuracy: 0.9911 - val_loss: 0.0269 - val_accuracy: 0.9940
# Epoch 12/20
# 981/981 [==============================] - 147s 149ms/step - loss: 0.0302 - accuracy: 0.9909 - val_loss: 0.0284 - val_accuracy: 0.9953
# Epoch 13/20
# 981/981 [==============================] - 136s 139ms/step - loss: 0.0233 - accuracy: 0.9922 - val_loss: 0.0179 - val_accuracy: 0.9959
# Epoch 14/20
# 981/981 [==============================] - 134s 136ms/step - loss: 0.0229 - accuracy: 0.9933 - val_loss: 0.0380 - val_accuracy: 0.9916
# Epoch 15/20
# 981/981 [==============================] - 134s 137ms/step - loss: 0.0192 - accuracy: 0.9939 - val_loss: 0.0583 - val_accuracy: 0.9925
# Epoch 16/20
# 981/981 [==============================] - 134s 137ms/step - loss: 0.0194 - accuracy: 0.9938 - val_loss: 0.0120 - val_accuracy: 0.9973
# Epoch 17/20
# 981/981 [==============================] - 134s 137ms/step - loss: 0.0259 - accuracy: 0.9922 - val_loss: 0.0249 - val_accuracy: 0.9959
# Epoch 18/20
# 981/981 [==============================] - 134s 136ms/step - loss: 0.0181 - accuracy: 0.9945 - val_loss: 0.0202 - val_accuracy: 0.9969
# Epoch 19/20
# 981/981 [==============================] - 134s 136ms/step - loss: 0.0130 - accuracy: 0.9959 - val_loss: 0.0153 - val_accuracy: 0.9968
# Epoch 20/20
# 981/981 [==============================] - 139s 142ms/step - loss: 0.0168 - accuracy: 0.9951 - val_loss: 0.0204 - val_accuracy: 0.9954

# %%
#plotting graphs for accuracy 
plt.figure(0)
plt.plot(model4_1.history['accuracy'], label='training accuracy')
plt.plot(model4_1.history['val_accuracy'], label='val accuracy')
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
#plotting graphs for loss 
plt.figure(1)
plt.plot(model4_1.history['loss'], label='training loss')
plt.plot(model4_1.history['val_loss'], label='val loss')
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
pd.DataFrame(model4_1.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %% [markdown]
# ##### Test trained model

# %%
score_4_1 = cnn4_1.evaluate(X_test, y_test, verbose=0)

print('Test Score:', score_4_1[0])
print('Test Accuracy:', score_4_1[1])
# Out:
# Test Score: 0.07108211517333984
# Test Accuracy: 0.9832145571708679

# %%
# Save the model
cnn4_1.save('trained_models/cnn4_1_' + str(int(score_4_1[1]*100)) + '.h5')

# %%
# Model3 confusion matrix
y_pred = cnn4_1.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis = 1)
y_true = np.argmax(y_test, axis = 1)
cm_4_1 = confusion_matrix(y_true, y_pred_classes)

# Plot confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm_4_1, annot=False, fmt='d')
plt.title('Confusion Matrix for CNN3')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# Accuracy by class
diagonal = np.diag(cm_4_1)
# Use the percentage of correct predictions
diagonal = diagonal/cm_4_1.sum(axis=1)*100
plt.bar(range(len(diagonal)), diagonal)
plt.xlabel('Class')
plt.ylabel('Number of correct predictions')
plt.title('Accuracy by class for CNN3')
plt.show()

# Classification report
print(classification_report(y_true, y_pred_classes))
# Out:
# 395/395 [==============================] - 14s 33ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        60
#            1       1.00      0.99      0.99       720
#            2       1.00      1.00      1.00       750
#            3       0.99      0.97      0.98       450
#            4       1.00      0.99      0.99       660
#            5       0.96      0.99      0.97       630
#            6       1.00      0.93      0.96       150
#            7       0.98      0.99      0.99       450
#            8       0.98      0.98      0.98       450
#            9       0.97      1.00      0.99       480
#           10       1.00      1.00      1.00       660
#           11       0.99      0.99      0.99       420
#           12       0.97      0.99      0.98       690
#           13       0.98      1.00      0.99       720
#           14       1.00      1.00      1.00       270
#           15       0.99      1.00      0.99       210
#           16       1.00      0.99      1.00       150
#           17       1.00      1.00      1.00       360
#           18       0.99      0.97      0.98       390
#           19       0.97      1.00      0.98        60
#           20       0.85      1.00      0.92        90
#           21       0.98      0.97      0.97        90
#           22       0.83      0.93      0.87       120
#           23       0.99      1.00      0.99       150
#           24       1.00      0.97      0.98        90
#           25       0.96      1.00      0.98       480
#           26       1.00      0.84      0.92       180
#           27       0.97      1.00      0.98        60
#           28       1.00      1.00      1.00       150
#           29       0.89      1.00      0.94        90
#           30       1.00      0.87      0.93       150
#           31       0.99      0.99      0.99       270
#           32       0.87      1.00      0.93        60
#           33       1.00      0.98      0.99       210
#           34       0.99      0.98      0.99       120
#           35       0.99      0.98      0.99       390
#           36       0.98      0.95      0.97       120
#           37       1.00      1.00      1.00        60
#           38       1.00      0.99      0.99       690
#           39       1.00      1.00      1.00        90
#           40       1.00      0.96      0.98        90
#           41       1.00      0.78      0.88        60
#           42       1.00      0.87      0.93        90
#
#     accuracy                           0.98     12630
#    macro avg       0.98      0.97      0.97     12630
# weighted avg       0.98      0.98      0.98     12630

# %%
# Sum the quantity of correct predictions
correct_predictinons = sum(np.diag(cm_4_1))
# Sum the quantity of incorrect predictions
total_predictions = sum(sum(cm_4_1))

# Accuracy
accuracy = correct_predictinons/total_predictions

# Save wrong predictions into a variable for further analysis
wrong_predictions_4_1 = np.where(y_pred_classes != y_true)[0]

# %% [markdown]
# ##### Joining the best two models

# %%
# The same as before but using the full test set
predicted3 = cnn3.predict(X_test)
predicted4_1 = cnn4_1.predict(X_test)

# Sum the probabilities of the three models
predicted_sum = predicted3 + predicted4_1

# Compare the predicted class with the real class
predicted_classes = np.argmax(predicted_sum, axis = 1)
real_classes = np.argmax(y_test, axis = 1)

# Print the accuracy
print("Accuracy:", sum(predicted_classes == real_classes)/len(real_classes))
# Out:
# 395/395 [==============================] - 5s 11ms/step
# 395/395 [==============================] - 12s 30ms/step
# Accuracy: 0.9883610451306414
